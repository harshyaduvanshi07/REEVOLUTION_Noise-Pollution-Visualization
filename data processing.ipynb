# %%
import pandas as pd

# %%
data = pd.read_csv("C:/Users/harsh/Downloads/archive/station_month.csv")

# %%
data.drop_duplicates(inplace=True)

# %%
data.head
# Out:
# <bound method NDFrame.head of      Station  Year  Month   Day  Night  DayLimit  NightLimit
# 0      BEN01  2011      2  66.0   56.0        55          45
# 1      BEN01  2011      3  66.0   58.0        55          45
# 2      BEN01  2011      4  66.0   57.0        55          45
# 3      BEN01  2011      5  66.0   56.0        55          45
# 4      BEN01  2011      6  67.0   57.0        55          45
# ...      ...   ...    ...   ...    ...       ...         ...
# 5000   MUM10  2018      8  73.0   69.0        65          55
# 5001   MUM10  2018      9  72.0   68.0        65          55
# 5002   MUM10  2018     10  73.0   68.0        65          55
# 5003   MUM10  2018     11  72.0   68.0        65          55
# 5004   MUM10  2018     12  72.0   68.0        65          55
#
# [5005 rows x 7 columns]>

# %%
#data['Year'] = pd.to_datetime(data['Year'])

# %%
#data.to_csv('C:/Users/harsh/Downloads/archive/processed_data.csv', index=False)

# %%
import matplotlib.pyplot as plt

# %%
#data = pd.read_csv('C:/Users/harsh/Downloads/archive/processed_data.csv')

# %%
plt.figure(figsize=(10, 5))

# %%
for location in data['Station'].unique():
    subset = data[data['Station'] == location]
    plt.plot(subset['Year'], subset['Day'], label=location)
    
plt.title('Noise Pollution Levels Over Time')
plt.xlabel('Date')
plt.ylabel('Noise Level (dB)')

plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('C:/Users/harsh/Downloads/archive/noise_plot.png')
plt.show()
